# %% [markdown]
# # Electricity Price Prediction

# %%
import pandas as pd
import numpy as np
import warnings

# Load the data

file = (r'C:/Users/CA/Projects/Sandor_Time_Series_Forcasting/han/data_decoded(AutoRecovered).csv')

df = pd.read_csv(file)
df.head()
# Out:
#   ForecastIssueDateHourUTC      DeliveryStartUTC  target_var  product_type  \
# 0     2016-12-31T10:00:00Z  2016-12-31T23:00:00Z       42.88             1
# 1     2016-12-31T10:00:00Z  2017-01-01T00:00:00Z       42.95             2
# 2     2016-12-31T10:00:00Z  2017-01-01T01:00:00Z       41.66             3
# 3     2016-12-31T10:00:00Z  2017-01-01T02:00:00Z       33.77             4
# 4     2016-12-31T10:00:00Z  2017-01-01T03:00:00Z       37.65             5
#
#    auction_price  demand_forcast  solar_production_forcast  \
# 0          20.96             NaN                       NaN
# 1          20.90             NaN                       NaN
# 2          18.13             NaN                       NaN
# 3          16.03             NaN                       NaN
# 4          16.43             NaN                       NaN
#
#    wind_production_forcast  co2_price  natural_gas_price  \
# 0                      NaN        NaN                NaN
# 1                      NaN        NaN                NaN
# 2                      NaN        NaN                NaN
# 3                      NaN        NaN                NaN
# 4                      NaN        NaN                NaN
#
#    non_renewable_consumption  predictor_var8^2  predictor_var8^3
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN

# %%
warnings.simplefilter(action='ignore', category=(FutureWarning, UserWarning))

# %%
df.describe().round()
# Out:
#        target_var  product_type  auction_price  demand_forcast  \
# count     43823.0       43824.0        43824.0         43800.0
# mean         49.0          12.0           49.0         55207.0
# std          45.0           7.0           44.0          9557.0
# min        -445.0           1.0          -90.0         32886.0
# 25%          30.0           7.0           30.0         47160.0
# 50%          40.0          12.0           40.0         54895.0
# 75%          54.0          18.0           54.0         63552.0
# max         911.0          24.0          620.0         86117.0
#
#        solar_production_forcast  wind_production_forcast  co2_price  \
# count                   43800.0                  43800.0    43752.0
# mean                     4804.0                  12887.0       25.0
# std                      7331.0                   9944.0       17.0
# min                         0.0                     92.0        4.0
# 25%                         0.0                   5150.0       13.0
# 50%                       113.0                  10145.0       23.0
# 75%                      7723.0                  18151.0       28.0
# max                     33394.0                  46151.0       88.0
#
#        natural_gas_price  non_renewable_consumption  predictor_var8^2  \
# count            43728.0                    43800.0      4.380000e+04
# mean                22.0                    37516.0      1.568870e+09
# std                 20.0                    12705.0      9.319734e+08
# min                  4.0                   -10698.0      3.830000e+02
# 25%                 14.0                    29647.0      8.789333e+08
# 50%                 18.0                    38129.0      1.453808e+09
# 75%                 22.0                    46251.0      2.139124e+09
# max                175.0                    78322.0      6.134405e+09
#
#        predictor_var8^3
# count      4.380000e+04
# mean       7.035164e+13
# std        5.926229e+13
# min       -1.220000e+12
# 25%        2.610000e+13
# 50%        5.540000e+13
# 75%        9.890000e+13
# max        4.800000e+14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ForecastIssueDateHourUTC   43824 non-null  object
#  1   DeliveryStartUTC           43824 non-null  object
#  2   target_var                 43823 non-null  float64
#  3   product_type               43824 non-null  int64
#  4   auction_price              43824 non-null  float64
#  5   demand_forcast             43800 non-null  float64
#  6   solar_production_forcast   43800 non-null  float64
#  7   wind_production_forcast    43800 non-null  float64
#  8   co2_price                  43752 non-null  float64
#  9   natural_gas_price          43728 non-null  float64
#  10  non_renewable_consumption  43800 non-null  float64
#  11  predictor_var8^2           43800 non-null  float64
#  12  predictor_var8^3           43800 non-null  float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 4.3+ MB

# %% [markdown]
# ### We need to convert DeliveryStartsUTC column to datatime format and set it to index for further analysis

# %%
# Convert time to datetime object and set it as index

df.drop(df.loc[df['DeliveryStartUTC'].duplicated()].index, inplace = True)
df['DeliveryStartUTC'] = pd.to_datetime(df['DeliveryStartUTC'], utc=True, infer_datetime_format=True)
df = df.set_index(['DeliveryStartUTC'])
df.head()
# Out:
#                           ForecastIssueDateHourUTC  target_var  product_type  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00     2016-12-31T10:00:00Z       42.88             1
# 2017-01-01 00:00:00+00:00     2016-12-31T10:00:00Z       42.95             2
# 2017-01-01 01:00:00+00:00     2016-12-31T10:00:00Z       41.66             3
# 2017-01-01 02:00:00+00:00     2016-12-31T10:00:00Z       33.77             4
# 2017-01-01 03:00:00+00:00     2016-12-31T10:00:00Z       37.65             5
#
#                            auction_price  demand_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00          20.96             NaN
# 2017-01-01 00:00:00+00:00          20.90             NaN
# 2017-01-01 01:00:00+00:00          18.13             NaN
# 2017-01-01 02:00:00+00:00          16.03             NaN
# 2017-01-01 03:00:00+00:00          16.43             NaN
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                       NaN                      NaN
# 2017-01-01 00:00:00+00:00                       NaN                      NaN
# 2017-01-01 01:00:00+00:00                       NaN                      NaN
# 2017-01-01 02:00:00+00:00                       NaN                      NaN
# 2017-01-01 03:00:00+00:00                       NaN                      NaN
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00        NaN                NaN
# 2017-01-01 00:00:00+00:00        NaN                NaN
# 2017-01-01 01:00:00+00:00        NaN                NaN
# 2017-01-01 02:00:00+00:00        NaN                NaN
# 2017-01-01 03:00:00+00:00        NaN                NaN
#
#                            non_renewable_consumption  predictor_var8^2  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                        NaN               NaN
# 2017-01-01 00:00:00+00:00                        NaN               NaN
# 2017-01-01 01:00:00+00:00                        NaN               NaN
# 2017-01-01 02:00:00+00:00                        NaN               NaN
# 2017-01-01 03:00:00+00:00                        NaN               NaN
#
#                            predictor_var8^3
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00               NaN
# 2017-01-01 00:00:00+00:00               NaN
# 2017-01-01 01:00:00+00:00               NaN
# 2017-01-01 02:00:00+00:00               NaN
# 2017-01-01 03:00:00+00:00               NaN

# %% [markdown]
# AS we can see there is a lot of columns present in our data set that are not required at this moment and will only affect the model perfornmance, so better to drop extra columns.

# %%
## droping the columns that are not useful

df = df.drop(['ForecastIssueDateHourUTC','auction_price', 'product_type',
              'predictor_var8^2', 'predictor_var8^3'], axis=1)
df.head()
# Out:
#                            target_var  demand_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00       42.88             NaN
# 2017-01-01 00:00:00+00:00       42.95             NaN
# 2017-01-01 01:00:00+00:00       41.66             NaN
# 2017-01-01 02:00:00+00:00       33.77             NaN
# 2017-01-01 03:00:00+00:00       37.65             NaN
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                       NaN                      NaN
# 2017-01-01 00:00:00+00:00                       NaN                      NaN
# 2017-01-01 01:00:00+00:00                       NaN                      NaN
# 2017-01-01 02:00:00+00:00                       NaN                      NaN
# 2017-01-01 03:00:00+00:00                       NaN                      NaN
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00        NaN                NaN
# 2017-01-01 00:00:00+00:00        NaN                NaN
# 2017-01-01 01:00:00+00:00        NaN                NaN
# 2017-01-01 02:00:00+00:00        NaN                NaN
# 2017-01-01 03:00:00+00:00        NaN                NaN
#
#                            non_renewable_consumption
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                        NaN
# 2017-01-01 00:00:00+00:00                        NaN
# 2017-01-01 01:00:00+00:00                        NaN
# 2017-01-01 02:00:00+00:00                        NaN
# 2017-01-01 03:00:00+00:00                        NaN

# %% [markdown]
# We can see there is a large amount of NaN values in our dataset so, we need to replace them with the mean of the column as it will create noise in the data.

# %%
df['target_var'] = df['target_var'].fillna(df['target_var'].mean())
df['demand_forcast'] = df['demand_forcast'].fillna(df['demand_forcast'].mean())
df['solar_production_forcast'] = df['solar_production_forcast'].fillna(df['solar_production_forcast'].mean())
df['wind_production_forcast'] = df['wind_production_forcast'].fillna(df['wind_production_forcast'].mean())
df['co2_price'] = df['co2_price'].fillna(df['co2_price'].mean())
df['natural_gas_price'] = df['natural_gas_price'].fillna(df['natural_gas_price'].mean())
df['non_renewable_consumption'] = df['non_renewable_consumption'].fillna(df['non_renewable_consumption'].mean())

# %%
# Let's check our data set once again

df.head()
# Out:
#                            target_var  demand_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00       42.88    55206.791193
# 2017-01-01 00:00:00+00:00       42.95    55206.791193
# 2017-01-01 01:00:00+00:00       41.66    55206.791193
# 2017-01-01 02:00:00+00:00       33.77    55206.791193
# 2017-01-01 03:00:00+00:00       37.65    55206.791193
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 00:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 01:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 02:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 03:00:00+00:00               4803.733794             12887.083316
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00  24.848974          22.182827
# 2017-01-01 00:00:00+00:00  24.848974          22.182827
# 2017-01-01 01:00:00+00:00  24.848974          22.182827
# 2017-01-01 02:00:00+00:00  24.848974          22.182827
# 2017-01-01 03:00:00+00:00  24.848974          22.182827
#
#                            non_renewable_consumption
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00               37515.974083
# 2017-01-01 00:00:00+00:00               37515.974083
# 2017-01-01 01:00:00+00:00               37515.974083
# 2017-01-01 02:00:00+00:00               37515.974083
# 2017-01-01 03:00:00+00:00               37515.974083

# %%
# Find NaNs and duplicates in dataframe 'df'

print('There are {} missing values or NaNs in df.'
      .format(df.isnull().values.sum()))

temp = df.duplicated(keep='first').sum()

print('There are {} duplicate rows in df based on all columns.'
      .format(temp))
# Out:
# There are 0 missing values or NaNs in df.
# There are 0 duplicate rows in df based on all columns.

# %% [markdown]
# ### Moving forward in this analysis we need to add next 2 weeks data  with first year data.Selecting data points from 2017-01-01 00:00:00 to 2018-01-14 23:00:00 as it will complete one year data + next two weeks.

# %%
df = df.iloc[:9097]
df = df.iloc[1:]
df
# Out:
#                            target_var  demand_forcast  \
# DeliveryStartUTC
# 2017-01-01 00:00:00+00:00       42.95    55206.791193
# 2017-01-01 01:00:00+00:00       41.66    55206.791193
# 2017-01-01 02:00:00+00:00       33.77    55206.791193
# 2017-01-01 03:00:00+00:00       37.65    55206.791193
# 2017-01-01 04:00:00+00:00       33.88    55206.791193
# ...                               ...             ...
# 2018-01-14 19:00:00+00:00       29.51    51232.382750
# 2018-01-14 20:00:00+00:00       31.38    50617.329750
# 2018-01-14 21:00:00+00:00       29.37    47184.487000
# 2018-01-14 22:00:00+00:00       22.94    44672.907250
# 2018-01-14 23:00:00+00:00       20.22    42996.556250
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2017-01-01 00:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 01:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 02:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 03:00:00+00:00               4803.733794             12887.083316
# 2017-01-01 04:00:00+00:00               4803.733794             12887.083316
# ...                                             ...                      ...
# 2018-01-14 19:00:00+00:00                  0.000000             17238.850000
# 2018-01-14 20:00:00+00:00                  0.000000             17029.725000
# 2018-01-14 21:00:00+00:00                  0.000000             16560.175000
# 2018-01-14 22:00:00+00:00                  0.000000             15875.275000
# 2018-01-14 23:00:00+00:00                  0.000000             18356.600000
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2017-01-01 00:00:00+00:00  24.848974          22.182827
# 2017-01-01 01:00:00+00:00  24.848974          22.182827
# 2017-01-01 02:00:00+00:00  24.848974          22.182827
# 2017-01-01 03:00:00+00:00  24.848974          22.182827
# 2017-01-01 04:00:00+00:00  24.848974          22.182827
# ...                              ...                ...
# 2018-01-14 19:00:00+00:00   7.830000          19.565000
# 2018-01-14 20:00:00+00:00   7.830000          19.565000
# 2018-01-14 21:00:00+00:00   7.830000          19.565000
# 2018-01-14 22:00:00+00:00   7.830000          19.565000
# 2018-01-14 23:00:00+00:00   7.830000          19.565000
#
#                            non_renewable_consumption
# DeliveryStartUTC
# 2017-01-01 00:00:00+00:00               37515.974083
# 2017-01-01 01:00:00+00:00               37515.974083
# 2017-01-01 02:00:00+00:00               37515.974083
# 2017-01-01 03:00:00+00:00               37515.974083
# 2017-01-01 04:00:00+00:00               37515.974083
# ...                                              ...
# 2018-01-14 19:00:00+00:00               33993.532750
# 2018-01-14 20:00:00+00:00               33587.604750
# 2018-01-14 21:00:00+00:00               30624.312000
# 2018-01-14 22:00:00+00:00               28797.632250
# 2018-01-14 23:00:00+00:00               24639.956250
#
# [9096 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlations = df.corr(method='pearson')
plt.figure(figsize=(16, 12))
sns.heatmap(correlations, cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
# ## Prediction Model
# Now let’s move to the task of training a price prediction model. Here I will first add all the important features to x and the target column to y, and then I will split the data into training and test sets:

# %%
x = df[['demand_forcast','solar_production_forcast',
        'wind_production_forcast', 'co2_price',
        'natural_gas_price', 'non_renewable_consumption']]

y = df["target_var"]

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, 
                                                test_size=0.25, 
                                                random_state=42)

# %%
# Checking the shape of our data set 

print('Training Features Shape:', xtrain.shape)
print('Training Labels Shape:', ytrain.shape)
print('Testing Features Shape:', xtest.shape)
print('Testing Labels Shape:', ytest.shape)
# Out:
# Training Features Shape: (6822, 6)
# Training Labels Shape: (6822,)
# Testing Features Shape: (2274, 6)
# Testing Labels Shape: (2274,)

# %% [markdown]
# As this is the problem of regression, so here I will choose the Random Forest regression algorithm to train the price prediction model:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import metrics


## Define Grid 
grid = { 
    'n_estimators': [200,300,400,500],
    'max_features': ['sqrt','log2'],
    'max_depth' : [3,4,5,6,7],
    'random_state' : [18]
}


model = GridSearchCV(RandomForestRegressor(n_jobs=3), grid, cv=5, n_jobs=1)
fit = model.fit(xtrain, ytrain)


# Best Estimator
rf = fit.best_estimator_

# %% [markdown]
# ### Let's predict the price.

# %%
y_pred = model.predict(xtest)
y_pred
# Out:
# array([37.46007094, 21.47454305, 45.19880112, ..., 39.20993831,
#        47.29901653, 61.44267459])

# %% [markdown]
# ### Let’s check the difference between the actual and predicted values.

# %%
result=pd.DataFrame({'Actual':ytest, 'Predicted':y_pred})
result
# Out:
#                            Actual  Predicted
# DeliveryStartUTC
# 2017-11-14 00:00:00+00:00   35.33  37.460071
# 2017-07-02 08:00:00+00:00   21.47  21.474543
# 2017-09-21 16:00:00+00:00   46.13  45.198801
# 2017-05-25 02:00:00+00:00   24.60  34.029040
# 2017-10-01 01:00:00+00:00   20.18  26.698296
# ...                           ...        ...
# 2017-09-05 01:00:00+00:00   31.23  34.137119
# 2017-02-21 18:00:00+00:00   49.37  37.456747
# 2017-11-16 03:00:00+00:00   33.58  39.209938
# 2017-07-10 07:00:00+00:00   54.67  47.299017
# 2017-01-23 19:00:00+00:00  100.19  61.442675
#
# [2274 rows x 2 columns]

# %%
# Calculate the absolute errors
errors = abs(y_pred - ytest)

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / ytest)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 58.03 %.

# %% [markdown]
# ### For our use case we need to predict the prices for next two weeks we need to create an array with the values of next two weeks and then pass it to our model and see how our model perform with the new input

# %%
df_test = pd.read_csv(file)
df_test.head()
# Out:
#   ForecastIssueDateHourUTC      DeliveryStartUTC  target_var  product_type  \
# 0     2016-12-31T10:00:00Z  2016-12-31T23:00:00Z       42.88             1
# 1     2016-12-31T10:00:00Z  2017-01-01T00:00:00Z       42.95             2
# 2     2016-12-31T10:00:00Z  2017-01-01T01:00:00Z       41.66             3
# 3     2016-12-31T10:00:00Z  2017-01-01T02:00:00Z       33.77             4
# 4     2016-12-31T10:00:00Z  2017-01-01T03:00:00Z       37.65             5
#
#    auction_price  demand_forcast  solar_production_forcast  \
# 0          20.96             NaN                       NaN
# 1          20.90             NaN                       NaN
# 2          18.13             NaN                       NaN
# 3          16.03             NaN                       NaN
# 4          16.43             NaN                       NaN
#
#    wind_production_forcast  co2_price  natural_gas_price  \
# 0                      NaN        NaN                NaN
# 1                      NaN        NaN                NaN
# 2                      NaN        NaN                NaN
# 3                      NaN        NaN                NaN
# 4                      NaN        NaN                NaN
#
#    non_renewable_consumption  predictor_var8^2  predictor_var8^3
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN

# %%
# Convert time to datetime object and set it as index

df_test.drop(df_test.loc[df_test['DeliveryStartUTC'].duplicated()].index, inplace = True)
df_test['DeliveryStartUTC'] = pd.to_datetime(df_test['DeliveryStartUTC'], utc=True, infer_datetime_format=True)
df_test = df_test.set_index(['DeliveryStartUTC'])
df_test.head()
# Out:
#                           ForecastIssueDateHourUTC  target_var  product_type  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00     2016-12-31T10:00:00Z       42.88             1
# 2017-01-01 00:00:00+00:00     2016-12-31T10:00:00Z       42.95             2
# 2017-01-01 01:00:00+00:00     2016-12-31T10:00:00Z       41.66             3
# 2017-01-01 02:00:00+00:00     2016-12-31T10:00:00Z       33.77             4
# 2017-01-01 03:00:00+00:00     2016-12-31T10:00:00Z       37.65             5
#
#                            auction_price  demand_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00          20.96             NaN
# 2017-01-01 00:00:00+00:00          20.90             NaN
# 2017-01-01 01:00:00+00:00          18.13             NaN
# 2017-01-01 02:00:00+00:00          16.03             NaN
# 2017-01-01 03:00:00+00:00          16.43             NaN
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                       NaN                      NaN
# 2017-01-01 00:00:00+00:00                       NaN                      NaN
# 2017-01-01 01:00:00+00:00                       NaN                      NaN
# 2017-01-01 02:00:00+00:00                       NaN                      NaN
# 2017-01-01 03:00:00+00:00                       NaN                      NaN
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00        NaN                NaN
# 2017-01-01 00:00:00+00:00        NaN                NaN
# 2017-01-01 01:00:00+00:00        NaN                NaN
# 2017-01-01 02:00:00+00:00        NaN                NaN
# 2017-01-01 03:00:00+00:00        NaN                NaN
#
#                            non_renewable_consumption  predictor_var8^2  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                        NaN               NaN
# 2017-01-01 00:00:00+00:00                        NaN               NaN
# 2017-01-01 01:00:00+00:00                        NaN               NaN
# 2017-01-01 02:00:00+00:00                        NaN               NaN
# 2017-01-01 03:00:00+00:00                        NaN               NaN
#
#                            predictor_var8^3
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00               NaN
# 2017-01-01 00:00:00+00:00               NaN
# 2017-01-01 01:00:00+00:00               NaN
# 2017-01-01 02:00:00+00:00               NaN
# 2017-01-01 03:00:00+00:00               NaN

# %%
## droping the columns that are not useful

df_test = df_test.drop(['ForecastIssueDateHourUTC','auction_price', 'product_type',
                        'predictor_var8^2', 'predictor_var8^3'], axis=1)
df_test.head()
# Out:
#                            target_var  demand_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00       42.88             NaN
# 2017-01-01 00:00:00+00:00       42.95             NaN
# 2017-01-01 01:00:00+00:00       41.66             NaN
# 2017-01-01 02:00:00+00:00       33.77             NaN
# 2017-01-01 03:00:00+00:00       37.65             NaN
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                       NaN                      NaN
# 2017-01-01 00:00:00+00:00                       NaN                      NaN
# 2017-01-01 01:00:00+00:00                       NaN                      NaN
# 2017-01-01 02:00:00+00:00                       NaN                      NaN
# 2017-01-01 03:00:00+00:00                       NaN                      NaN
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00        NaN                NaN
# 2017-01-01 00:00:00+00:00        NaN                NaN
# 2017-01-01 01:00:00+00:00        NaN                NaN
# 2017-01-01 02:00:00+00:00        NaN                NaN
# 2017-01-01 03:00:00+00:00        NaN                NaN
#
#                            non_renewable_consumption
# DeliveryStartUTC
# 2016-12-31 23:00:00+00:00                        NaN
# 2017-01-01 00:00:00+00:00                        NaN
# 2017-01-01 01:00:00+00:00                        NaN
# 2017-01-01 02:00:00+00:00                        NaN
# 2017-01-01 03:00:00+00:00                        NaN

# %% [markdown]
# ### Taking data points for the period of next two weeks ( i.e - from 2018-01-15 00:00:00 to 2018-01-29 23:00:00)

# %%
df_test = df_test.iloc[:9457]
df_test = df_test.iloc[9097:]
df_test
# Out:
#                            target_var  demand_forcast  \
# DeliveryStartUTC
# 2018-01-15 00:00:00+00:00       18.59     42393.51050
# 2018-01-15 01:00:00+00:00       15.07     42952.02150
# 2018-01-15 02:00:00+00:00        8.71     44784.46700
# 2018-01-15 03:00:00+00:00       17.67     48724.93400
# 2018-01-15 04:00:00+00:00       23.34     56166.47200
# ...                               ...             ...
# 2018-01-29 19:00:00+00:00       19.67     55474.06550
# 2018-01-29 20:00:00+00:00       10.57     52085.59875
# 2018-01-29 21:00:00+00:00        8.76     48474.18675
# 2018-01-29 22:00:00+00:00        6.13     46007.18500
# 2018-01-29 23:00:00+00:00       11.53     44140.80975
#
#                            solar_production_forcast  wind_production_forcast  \
# DeliveryStartUTC
# 2018-01-15 00:00:00+00:00                       0.0                18637.675
# 2018-01-15 01:00:00+00:00                       0.0                19153.350
# 2018-01-15 02:00:00+00:00                       0.0                19635.100
# 2018-01-15 03:00:00+00:00                       0.0                20230.150
# 2018-01-15 04:00:00+00:00                       0.0                20956.125
# ...                                             ...                      ...
# 2018-01-29 19:00:00+00:00                       0.0                36715.700
# 2018-01-29 20:00:00+00:00                       0.0                36312.475
# 2018-01-29 21:00:00+00:00                       0.0                35747.100
# 2018-01-29 22:00:00+00:00                       0.0                34677.700
# 2018-01-29 23:00:00+00:00                       0.0                34313.725
#
#                            co2_price  natural_gas_price  \
# DeliveryStartUTC
# 2018-01-15 00:00:00+00:00       7.83             19.565
# 2018-01-15 01:00:00+00:00       7.83             19.565
# 2018-01-15 02:00:00+00:00       7.83             19.565
# 2018-01-15 03:00:00+00:00       7.83             19.565
# 2018-01-15 04:00:00+00:00       7.83             19.565
# ...                              ...                ...
# 2018-01-29 19:00:00+00:00       9.05             18.018
# 2018-01-29 20:00:00+00:00       9.05             18.018
# 2018-01-29 21:00:00+00:00       9.05             18.018
# 2018-01-29 22:00:00+00:00       9.05             18.018
# 2018-01-29 23:00:00+00:00       9.05             18.018
#
#                            non_renewable_consumption
# DeliveryStartUTC
# 2018-01-15 00:00:00+00:00                23755.83550
# 2018-01-15 01:00:00+00:00                23798.67150
# 2018-01-15 02:00:00+00:00                25149.36700
# 2018-01-15 03:00:00+00:00                28494.78400
# 2018-01-15 04:00:00+00:00                35210.34700
# ...                                              ...
# 2018-01-29 19:00:00+00:00                18758.36550
# 2018-01-29 20:00:00+00:00                15773.12375
# 2018-01-29 21:00:00+00:00                12727.08675
# 2018-01-29 22:00:00+00:00                11329.48500
# 2018-01-29 23:00:00+00:00                 9827.08475
#
# [360 rows x 7 columns]

# %%
# convert dataframe to numpy array
arr = df_test[['demand_forcast', 'solar_production_forcast',
               'wind_production_forcast', 'co2_price',
               'natural_gas_price', 'non_renewable_consumption']].to_numpy()
print(arr)
# Out:
# [[4.23935105e+04 0.00000000e+00 1.86376750e+04 7.83000000e+00
#   1.95650000e+01 2.37558355e+04]
#  [4.29520215e+04 0.00000000e+00 1.91533500e+04 7.83000000e+00
#   1.95650000e+01 2.37986715e+04]
#  [4.47844670e+04 0.00000000e+00 1.96351000e+04 7.83000000e+00
#   1.95650000e+01 2.51493670e+04]
#  ...
#  [4.84741868e+04 0.00000000e+00 3.57471000e+04 9.05000000e+00
#   1.80180000e+01 1.27270868e+04]
#  [4.60071850e+04 0.00000000e+00 3.46777000e+04 9.05000000e+00
#   1.80180000e+01 1.13294850e+04]
#  [4.41408098e+04 0.00000000e+00 3.43137250e+04 9.05000000e+00
#   1.80180000e+01 9.82708475e+03]]

# %% [markdown]
# ### Predicting the prices by passing new unseen data points to our model.

# %%
two_weeks = model.predict(arr)

# %%
result = two_weeks.tolist()

# %%
# Making a final Dataframe with predictions in it.

df_test['Predictions'] = result 
df_test = df_test.drop(['demand_forcast', 'solar_production_forcast',
                        'wind_production_forcast', 'natural_gas_price',
                         'co2_price', 'non_renewable_consumption'], axis=1)
df_test.head()
# Out:
#                            target_var  Predictions
# DeliveryStartUTC
# 2018-01-15 00:00:00+00:00       18.59    20.879419
# 2018-01-15 01:00:00+00:00       15.07    19.302869
# 2018-01-15 02:00:00+00:00        8.71    19.246772
# 2018-01-15 03:00:00+00:00       17.67    20.426227
# 2018-01-15 04:00:00+00:00       23.34    31.254903

# %% [markdown]
# ## Ploting Ling graph between target variable and Predicted values of our model

# %%
kwargs= dict (linestyle='solid', color=['red', 'green'], linewidth=1.2)
line_plot = df_test.plot( y = ['target_var', 'Predictions'], figsize= (10,6),**kwargs ) 
line_plot.set_title('Comparision -> "Actual vs Predicted"')
line_plot.grid()
line_plot.set_xlabel('Date')
line_plot.set_ylabel('Price');

# %% [markdown]
# ## We got our model running and getting good prediction let's check our model perfornmance

# %%
# Calculate the absolute errors
errors = abs(df_test['Predictions'] - df_test['target_var'])

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / df_test['target_var'])

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 42.93 %.

# %%
# Metrics
print('Best Params: ', fit.best_params_)
print('Best Score: ', fit.best_score_)
print( 'R2 Score: ', metrics.r2_score(ytest.values, y_pred))
print( 'Explained Variance Score: ', metrics.explained_variance_score(ytest.values, y_pred))
print( 'MAE: ', metrics.mean_absolute_error(ytest.values, y_pred))
print( 'MSE: ', metrics.mean_squared_error(ytest.values, y_pred))
print( 'Median AE: ', metrics.median_absolute_error(ytest.values, y_pred))
# Out:
# Best Params:  {'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 200, 'random_state': 18}
# Best Score:  0.7029464064193758
# R2 Score:  0.7094992102416823
# Explained Variance Score:  0.7094995774203796
# MAE:  7.303443858931732
# MSE:  125.2735242318213
# Median AE:  5.244079252234059
